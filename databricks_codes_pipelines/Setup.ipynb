# %%
# %sql
CREATE VOLUME flight_project.gold.goldvolume

# %%
dbutils.fs.mkdirs('/Volumes/flight_project/raw/rawvolume/raw_data/airports')

# %%
# %sql
CREATE SCHEMA flight_project.gold

# %%
# %sql
SELECT *
FROM delta.`/Volumes/flight_project/bronze/bronzevolume/airports/data/`
